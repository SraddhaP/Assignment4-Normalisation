# %%
import requests, json, re, os
from parsel import Selector
from serpapi import GoogleSearch
import pandas as pd
import numpy as np
import requests
import re
from bs4 import BeautifulSoup
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data gathering and scraping

# %%
# function for scraping data

def scrape_groceries(grocery_name):
    params = {"q": grocery_name, "hl": "en", "location_auto":False, "gl": "us", "tbm": "shop"}

    headers = {
        "User-Agent": "Mozilla/5.0 (Windows NT 10.0;  Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/103.0.0.0 Safari/537.36"
    }
    html = requests.get("https://www.google.com/search", params=params, headers=headers, timeout=30)
    selector = Selector(html.text)
    scraped_data = []
    for result in selector.css(".Qlx7of .i0X6df"):
        name = result.css(".tAxDx::text").get()
        product_link = "https://www.google.com" + result.css(".Lq5OHe::attr(href)").get()
        price = result.css(".a8Pemb::text").get()
        store = result.css(".aULzUe::text").get()
        rating = result.css(".NzUzee .Rsc7Yb::text").get()
        store_link = "https://www.google.com" + result.css(".eaGTj div a::attr(href)").get()
        delivery = result.css(".vEjMR::text").get()
        
        scraped_data.append({
            "grocery_name":grocery_name,
            "product_name": name,
            "product_price" : price,
            "store": store,
            "product_link": product_link,
            "product_rating": rating,
            "store_link" : store_link,
            "delivery": delivery
        })
       
    df = pd.DataFrame(scraped_data)
#     print(scraped_data)
    return df

# %%
# function call to scrape all the groecery products
grocery = ["mango", "Oranges", "Apple fruit", "Kiwi", "Banana", "Strawberry", "Dragon Fruit", 
           "Coconut", "Pineapple", "Lime", "Grapes", "Mangoes", "Apples", "Apple", "Kiwifruit", "Banana", 
           "Bananas", "Strawberries", "Passion Fruit Blend", "Pomegranate Dragon Fruit",
          "Lemon","Onion", "Potato", "Tomato", "Spinach", "Carrots", "Eggplant", "Bell Pepper", 
           "Broccoli", "Cucumber", "Chillies", "Avocado", "Lemons", "Potatoes", "Tomatoes", "Baby Spinach", 
           "Cauliflower", "Cucumbers", "Avacados","Sugar", "Salt", "Flour","Paneer", "Cheese", "Milk", "Yogurt", 
           "Egg", "Eggs"]
final_df = pd.concat([scrape_groceries(gro) for gro in grocery])
final_df.head()
# Out:
#                   delivery grocery_name  \
# 0       21.7 mi · In stock        mango
# 1        4.0 mi · In stock        mango
# 2  Delivery by Fri, Dec 16        mango
# 3  Delivery by Fri, Dec 16        mango
# 4            Free delivery        mango
#
#                                         product_link  \
# 0  https://www.google.com/shopping/product/110288...
# 1  https://www.google.com/shopping/product/181585...
# 2  https://www.google.com/url?url=https://kampala...
# 3  https://www.google.com/url?url=https://www.ins...
# 4  https://www.google.com/url?url=https://www.tha...
#
#                                      product_name product_price  \
# 0                                   Mango, 1 Each         $1.08
# 1               Fresh Mango Fruit, Size: One Size         $1.19
# 2               Fresh Mangoes - Ugandan - per kg.         $0.95
# 3                              Green Mango - each         $5.79
# 4  Mango Fresh ( 5 kgs ie, 12-15 big size Mangos)        $40.50
#
# ...

# %%
final_df.to_csv("data.csv", index=False)

# %%
final_df = pd.read_csv("data.csv")
final_df
# Out:
#                                            delivery grocery_name  \
# 0                                21.7 mi · In stock        mango
# 1                                 4.0 mi · In stock        mango
# 2                           Delivery by Fri, Dec 16        mango
# 3                           Delivery by Fri, Dec 16        mango
# 4                                     Free delivery        mango
# 5                           Delivery by Wed, Dec 21        mango
# 6                           Delivery by Wed, Dec 21        mango
# 7                                15.1 mi · In stock        mango
# 8                                     Free delivery        mango
# 9                                         +Shipping        mango
# 10                          Delivery by Thu, Dec 15        mango
# 11                          Delivery by Thu, Dec 22        mango
# 12                          Delivery by Mon, Dec 19        mango
# ...

# %% [markdown]
# ### Data cleaning and munging

# %%
# data for only selected merchants
merc = ["Target", "Walmart", "Sam's Club", "Instacart"]
df = final_df[final_df['store'].isin(merc)]

# %%
df['grocery_name'].unique()
df
# Out:
#                            delivery grocery_name  \
# 0                21.7 mi · In stock        mango
# 1                 4.0 mi · In stock        mango
# 3           Delivery by Fri, Dec 16        mango
# 7                15.1 mi · In stock        mango
# 14                  $59.43 delivery        mango
# 15                1.6 mi · In stock        mango
# 16          Delivery by Fri, Dec 16        mango
# 18                8.8 mi · In stock        mango
# 21          Delivery by Fri, Dec 16        mango
# 27    15.1 mi · In stock · Curbside        mango
# 61                4.0 mi · In stock      Oranges
# 63               15.1 mi · In stock      Oranges
# 65                1.6 mi · In stock      Oranges
# 67          31.9 mi · Limited stock      Oranges
# 68               24.2 mi · In stock      Oranges
# 76          Delivery by Fri, Dec 16      Oranges
# 77               26.7 mi · In stock      Oranges
# 79               24.0 mi · In stock      Oranges
# ...

# %%
df=df.reset_index(drop=True)
print(df.shape)
df.head()
# Out:
# (585, 8)
#                   delivery grocery_name  \
# 0       21.7 mi · In stock        mango
# 1        4.0 mi · In stock        mango
# 2  Delivery by Fri, Dec 16        mango
# 3       15.1 mi · In stock        mango
# 4          $59.43 delivery        mango
#
#                                         product_link  \
# 0  https://www.google.com/shopping/product/110288...
# 1  https://www.google.com/shopping/product/181585...
# 2  https://www.google.com/url?url=https://www.ins...
# 3  https://www.google.com/shopping/product/502590...
# 4  https://www.google.com/shopping/product/143930...
#
#                                         product_name product_price  \
# 0                                      Mango, 1 Each         $1.08
# 1                  Fresh Mango Fruit, Size: One Size         $1.19
# 2                                 Green Mango - each         $5.79
# 3  Freshness Guaranteed Mango Spears 16 oz, Size:...         $5.58
# ...

# %% [markdown]
# ### Converting Scrapped data to CSV

# %%
df.to_csv("scrapped_data.csv")

# %%
df.columns
# Out:
# Index(['delivery', 'grocery_name', 'product_link', 'product_name',
#        'product_price', 'product_rating', 'store', 'store_link'],
#       dtype='object')

# %%
# cleaning the data for product quantity and size

df['qty'] = df['product_name'].str.extract('(\d+\s*lbs?|\d+\s*ozs?|\d+\s*Each?|\d+\s*ct?|\d+\s*\n\tfl?)')
df['quantityno'] = df['product_name'].str.extract('(\d+\s*)')
# print(name_qty)

name_size=df['product_name'].str.split(',', 1, expand=True)

df['Name'] = name_size[0]
df
# Out:
#                           delivery grocery_name  \
# 0               21.7 mi · In stock        mango
# 1                4.0 mi · In stock        mango
# 2          Delivery by Fri, Dec 16        mango
# 3               15.1 mi · In stock        mango
# 4                  $59.43 delivery        mango
# 5                1.6 mi · In stock        mango
# 6          Delivery by Fri, Dec 16        mango
# 7                8.8 mi · In stock        mango
# 8          Delivery by Fri, Dec 16        mango
# 9    15.1 mi · In stock · Curbside        mango
# 10               4.0 mi · In stock      Oranges
# 11              15.1 mi · In stock      Oranges
# 12               1.6 mi · In stock      Oranges
# 13         31.9 mi · Limited stock      Oranges
# 14              24.2 mi · In stock      Oranges
# 15         Delivery by Fri, Dec 16      Oranges
# 16              26.7 mi · In stock      Oranges
# 17              24.0 mi · In stock      Oranges
# ...

# %%
# cleaning the data for distance and availabilty

delivery_dist = df['delivery'].str.split('·', 1, expand=True)
df['distance'] = delivery_dist[0]
df['availabilty'] = delivery_dist[1]
df.head()
# Out:
#                   delivery grocery_name  \
# 0       21.7 mi · In stock        mango
# 1        4.0 mi · In stock        mango
# 2  Delivery by Fri, Dec 16        mango
# 3       15.1 mi · In stock        mango
# 4          $59.43 delivery        mango
#
#                                         product_link  \
# 0  https://www.google.com/shopping/product/110288...
# 1  https://www.google.com/shopping/product/181585...
# 2  https://www.google.com/url?url=https://www.ins...
# 3  https://www.google.com/shopping/product/502590...
# 4  https://www.google.com/shopping/product/143930...
#
#                                         product_name product_price  \
# 0                                      Mango, 1 Each         $1.08
# 1                  Fresh Mango Fruit, Size: One Size         $1.19
# 2                                 Green Mango - each         $5.79
# 3  Freshness Guaranteed Mango Spears 16 oz, Size:...         $5.58
# ...

# %%
df.columns
# Out:
# Index(['delivery', 'grocery_name', 'product_link', 'product_name',
#        'product_price', 'product_rating', 'store', 'store_link', 'qty',
#        'quantityno', 'Name', 'distance', 'availabilty'],
#       dtype='object')

# %%
# cleaning the data for distance
df['distance'].unique()
# Out:
# array(['21.7 mi ', '4.0 mi ', 'Delivery by Fri, Dec 16', '15.1 mi ',
#        '$59.43 delivery', '1.6 mi ', '8.8 mi ', '31.9 mi ', '24.2 mi ',
#        '26.7 mi ', '24.0 mi ', '9.7 mi ', 'Delivery by tomorrow',
#        '1.9 mi ', '4.2 mi ', '2.6 mi ', '$6.99 delivery ', '15.4 mi ',
#        '9.9 mi ', '35.2 mi ', '16.0 mi ', '29.3 mi ', '27.9 mi ',
#        '35.5 mi ', '30.2 mi ', '16.1 mi ', nan, '0.8 mi ', '6.1 mi ',
#        'Free delivery & Free 90-day returns', 'Delivery by Wed, Dec 21',
#        '32.6 mi ', '32.9 mi ', '34.4 mi ', '16.2 mi ', '41.0 mi ',
#        'Free delivery', '31.8 mi ', '$61.61 delivery', '$118.84 delivery',
#        '5.3 mi ', '30.1 mi '], dtype=object)

# %%
df['distance'] = df['distance'].str.replace('mi', '')
df['distance'] = df['distance'].str.replace(r'(^.*Delivery.*$)','0')
df['distance'] = df['distance'].str.replace(r'(^.*delivery.*$)','0')
df['distance'] = df['distance'].str.replace('#NAME','0')
df['distance'] = df['distance'].str.replace('?','0')
df['distance'] = df['distance'].str.strip()

df['distance'].unique()
# Out:
# array(['21.7', '4.0', '0', '15.1', '1.6', '8.8', '31.9', '24.2', '26.7',
#        '24.0', '9.7', '1.9', '4.2', '2.6', '15.4', '9.9', '35.2', '16.0',
#        '29.3', '27.9', '35.5', '30.2', '16.1', nan, '0.8', '6.1', '32.6',
#        '32.9', '34.4', '16.2', '41.0', '31.8', '5.3', '30.1'],
#       dtype=object)

# %%
df['distance'] = df['distance'].astype(float)
df['distance'].unique()
# df.head()
# Out:
# array([21.7,  4. ,  0. , 15.1,  1.6,  8.8, 31.9, 24.2, 26.7, 24. ,  9.7,
#         1.9,  4.2,  2.6, 15.4,  9.9, 35.2, 16. , 29.3, 27.9, 35.5, 30.2,
#        16.1,  nan,  0.8,  6.1, 32.6, 32.9, 34.4, 16.2, 41. , 31.8,  5.3,
#        30.1])

# %%
df['availabilty'] = df['availabilty'].fillna("delivery only")

# %%
df
# Out:
#                           delivery grocery_name  \
# 0               21.7 mi · In stock        mango
# 1                4.0 mi · In stock        mango
# 2          Delivery by Fri, Dec 16        mango
# 3               15.1 mi · In stock        mango
# 4                  $59.43 delivery        mango
# 5                1.6 mi · In stock        mango
# 6          Delivery by Fri, Dec 16        mango
# 7                8.8 mi · In stock        mango
# 8          Delivery by Fri, Dec 16        mango
# 9    15.1 mi · In stock · Curbside        mango
# 10               4.0 mi · In stock      Oranges
# 11              15.1 mi · In stock      Oranges
# 12               1.6 mi · In stock      Oranges
# 13         31.9 mi · Limited stock      Oranges
# 14              24.2 mi · In stock      Oranges
# 15         Delivery by Fri, Dec 16      Oranges
# 16              26.7 mi · In stock      Oranges
# 17              24.0 mi · In stock      Oranges
# ...

# %%
# data cleaning
# check for Null values
df.isnull().sum()
# Out:
# delivery            3
# grocery_name        0
# product_link        0
# product_name        0
# product_price       0
# product_rating    110
# store               0
# store_link          0
# qty               181
# quantityno        127
# Name                0
# distance            3
# availabilty         0
# dtype: int64

# %%
#replace Null values with 0
mean_rating = round(df['product_rating'].mean(),1)
print(round(mean_rating,1))
df['product_rating'] = df['product_rating'].fillna(value=mean_rating)
df['availabilty'] = df['availabilty'].fillna(0)
df
# Out:
# 3.4
#                           delivery grocery_name  \
# 0               21.7 mi · In stock        mango
# 1                4.0 mi · In stock        mango
# 2          Delivery by Fri, Dec 16        mango
# 3               15.1 mi · In stock        mango
# 4                  $59.43 delivery        mango
# 5                1.6 mi · In stock        mango
# 6          Delivery by Fri, Dec 16        mango
# 7                8.8 mi · In stock        mango
# 8          Delivery by Fri, Dec 16        mango
# 9    15.1 mi · In stock · Curbside        mango
# 10               4.0 mi · In stock      Oranges
# 11              15.1 mi · In stock      Oranges
# 12               1.6 mi · In stock      Oranges
# 13         31.9 mi · Limited stock      Oranges
# 14              24.2 mi · In stock      Oranges
# 15         Delivery by Fri, Dec 16      Oranges
# 16              26.7 mi · In stock      Oranges
# 17              24.0 mi · In stock      Oranges
# ...

# %%
# cleaning and converting price to float
df['product_price'].unique()
df['product_price'] = df['product_price'].str.replace('$','')
df['product_price'] = df['product_price'].str.strip()
print (df['product_price'].dtypes)
df['product_price'] = df['product_price'].astype(float)
print (df['product_price'].dtypes)
# Out:
# object
# float64

# %%
df.drop(columns=['delivery'], inplace=True)
df.head()
# Out:
#   grocery_name                                       product_link  \
# 0        mango  https://www.google.com/shopping/product/110288...
# 1        mango  https://www.google.com/shopping/product/181585...
# 2        mango  https://www.google.com/url?url=https://www.ins...
# 3        mango  https://www.google.com/shopping/product/502590...
# 4        mango  https://www.google.com/shopping/product/143930...
#
#                                         product_name  product_price  \
# 0                                      Mango, 1 Each           1.08
# 1                  Fresh Mango Fruit, Size: One Size           1.19
# 2                                 Green Mango - each           5.79
# 3  Freshness Guaranteed Mango Spears 16 oz, Size:...           5.58
# 4   The Giumarra Companies Australian Mangos (3 ct.)          25.98
#
#    product_rating       store  \
# 0             1.8     Walmart
# 1             3.4      Target
# 2             3.4   Instacart
# ...

# %%
# categorize each grocery product

fruits = ["mango", "Oranges", "Apple fruit", "Kiwi", "Banana", "Strawberry", "Dragon Fruit", "Coconut", "Pineapple", "Lime", "Grapes", "Mangoes", "Apples", "Apple", "Kiwifruit", "Banana", "Bananas", "Strawberries", "Passion Fruit Blend", "Pomegranate Dragon Fruit"]
vegetables = ["Lemon","Onion", "Potato", "Tomato", "Spinach", "Carrots", "Eggplant", "Bell Pepper", "Broccoli", "Cucumber", "Chillies", "Avocado", "Lemons", "Potatoes", "Tomatoes", "Baby Spinach", "Cauliflower", "Cucumbers", "Avacados"]
dairy = ["Paneer", "Cheese", "Milk", "Yogurt", "Egg", "Eggs", "Paneer"]
essentials = ["Sugar", "Salt", "Flour"]
snacks = ["biscuits", "chips"]
oils = ["Oils", "Oil"]
beverages = ["Juice"]
df['category']=''
for index,val in df.iterrows():
    if val['grocery_name'] in fruits:
        df['category'][df.index == index] ='fruits'
    elif val['grocery_name'] in oils:
        df['category'][df.index == index]  = 'oils'
    elif val['grocery_name'] in snacks:
        df['category'][df.index == index] = 'snacks'
    elif val['grocery_name'] in essentials:
        df['category'][df.index == index] = 'essentials'
    elif val['grocery_name'] in dairy:
        df['category'][df.index == index]  ='dairy'    
    elif val['grocery_name'] in vegetables:
        df['category'][df.index == index]  = 'vegetables'   
    elif val['grocery_name'] in beverages:
        df['category'][df.index == index]  = 'beverages'   
    else:
        pass
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
df
# Out:
#     grocery_name                                       product_link  \
# 0          mango  https://www.google.com/shopping/product/110288...
# 1          mango  https://www.google.com/shopping/product/181585...
# 2          mango  https://www.google.com/url?url=https://www.ins...
# 3          mango  https://www.google.com/shopping/product/502590...
# 4          mango  https://www.google.com/shopping/product/143930...
# 5          mango  https://www.google.com/shopping/product/163619...
# 6          mango  https://www.google.com/shopping/product/764950...
# 7          mango  https://www.google.com/shopping/product/181432...
# 8          mango  https://www.google.com/shopping/product/166091...
# 9          mango  https://www.google.com/shopping/product/181933...
# 10       Oranges  https://www.google.com/shopping/product/140746...
# 11       Oranges  https://www.google.com/url?url=https://www.wal...
# 12       Oranges  https://www.google.com/shopping/product/405311...
# ...

# %%
df.columns
# Out:
# Index(['grocery_name', 'product_link', 'product_name', 'product_price',
#        'product_rating', 'store', 'store_link', 'qty', 'quantityno', 'Name',
#        'distance', 'availabilty', 'category'],
#       dtype='object')

# %%
df.drop(columns=['quantityno'], inplace=True)

# %% [markdown]
# ### Creating Dataframe for respective merchants

# %%
walmart_products_df = df[df['store']=='Walmart']
target_products_df = df[df['store']=='Target']
samsclub_products_df = df[df['store']=="Sam's Club"]
instacart_products_df = df[df['store']=='Instacart']

# %%
walmart_products_df.head()
walmart_products_df.reset_index(drop=True)
# Out:
#      grocery_name                                       product_link  \
# 0           mango  https://www.google.com/shopping/product/110288...
# 1           mango  https://www.google.com/shopping/product/502590...
# 2           mango  https://www.google.com/shopping/product/181432...
# 3           mango  https://www.google.com/shopping/product/181933...
# 4         Oranges  https://www.google.com/url?url=https://www.wal...
# 5         Oranges  https://www.google.com/shopping/product/826450...
# 6         Oranges  https://www.google.com/shopping/product/754440...
# 7         Oranges  https://www.google.com/shopping/product/954729...
# 8     Apple fruit  https://www.google.com/shopping/product/700819...
# 9     Apple fruit  https://www.google.com/shopping/product/522337...
# 10    Apple fruit  https://www.google.com/shopping/product/742574...
# 11    Apple fruit  https://www.google.com/shopping/product/490075...
# 12           Kiwi  https://www.google.com/shopping/product/155023...
# ...

# %%
conditions=[(walmart_products_df.distance==26.7), (walmart_products_df.distance==29.3), (walmart_products_df.distance==21.7),
            (walmart_products_df.distance==15.1), (walmart_products_df.distance==9.7), (walmart_products_df.distance==24.2),
            (walmart_products_df.distance==9.9), (walmart_products_df.distance==8.8), (walmart_products_df.distance==15.4),
           (walmart_products_df.distance==12.1)]

zipc = ['02338', '01532', '01876',
        '02081', '01906', '01749',
        '01905', '02169', '02081',
       '02188']
walmart_products_df['zipcode']=np.select(conditions, zipc)
walmart_products_df.head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.
#    grocery_name                                       product_link  \
# 0         mango  https://www.google.com/shopping/product/110288...
# 3         mango  https://www.google.com/shopping/product/502590...
# 7         mango  https://www.google.com/shopping/product/181432...
# 9         mango  https://www.google.com/shopping/product/181933...
# 11      Oranges  https://www.google.com/url?url=https://www.wal...
#
#                                          product_name  product_price  \
# 0                                       Mango, 1 Each           1.08
# ...

# %%
conditions=[(samsclub_products_df.distance==31.9)]
zipc = ['03051']
samsclub_products_df['zipcode']=np.select(conditions, zipc)
samsclub_products_df
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                  grocery_name  \
# 4                       mango
# 13                    Oranges
# 29                Apple fruit
# 38                     Banana
# 40                     Banana
# 50                 Strawberry
# 72                  Pineapple
# 100                      Lime
# 102                    Grapes
# 105                    Grapes
# 109                    Grapes
# 122                   Mangoes
# 128                    Apples
# 136                    Apples
# 140                    Apples
# 147                     Apple
# ...

# %%
conditions=[(target_products_df.distance==3.2), (target_products_df.distance==2.6), (target_products_df.distance==5.8),
            (target_products_df.distance==5.1), (target_products_df.distance==9.7), (target_products_df.distance==24.2),
            (target_products_df.distance==9.9), (target_products_df.distance==8.8), (target_products_df.distance==15.4),
            (target_products_df.distance==12.1), (target_products_df.distance==4.0), (target_products_df.distance==1.6)]

zipc = ['02472', '02125', '02122',
        '98208', '01906', '01749',
        '01905', '02169', '02081','02188', '02131', '02215']
target_products_df['zipcode']=np.select(conditions, zipc)
target_products_df.head()
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#    grocery_name                                       product_link  \
# 1         mango  https://www.google.com/shopping/product/181585...
# 5         mango  https://www.google.com/shopping/product/163619...
# 10      Oranges  https://www.google.com/shopping/product/140746...
# 12      Oranges  https://www.google.com/shopping/product/405311...
# 17      Oranges  https://www.google.com/shopping/product/994947...
#
#                                         product_name  product_price  \
# 1                  Fresh Mango Fruit, Size: One Size           1.19
# ...

# %%
walmart_products_df.drop(columns=['distance'], inplace=True)
target_products_df.drop(columns=['distance'], inplace=True)
samsclub_products_df.drop(columns=['distance'], inplace=True)
# Out:
# C:\Users\user\Anaconda3\lib\site-packages\pandas\core\frame.py:3694: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
merchant = {'mechant_name':['Walmart', 'Target', 'Sams Club', 'Instacart'], 
            'merchant_URL':['https://www.walmart.com/', 'https://www.target.com/', 'https://www.samsclub.com/', 'https://www.instacart.com/store'],
               }
merchant_df = pd.DataFrame(merchant)
merchant_df
# Out:
#   mechant_name                     merchant_URL
# 0      Walmart         https://www.walmart.com/
# 1       Target          https://www.target.com/
# 2    Sams Club        https://www.samsclub.com/
# 3    Instacart  https://www.instacart.com/store

# %% [markdown]
# ### Scraping and cleaning data for merchants

# %%
def get_data(merchant_name, element, class_name):
    URL = f"https://www.yellowpages.com/boston-ma/{merchant_name}"
    page = requests.get(URL)
    soup = BeautifulSoup(page.content, "html.parser")
    data = soup.find_all(element, class_=class_name)
    return data

# %%
def create_df(merchant_name):
    merchant_df = pd.DataFrame()
    merchant = []
    city = []
    zipcode = []
    address =[]
    contact = []
    
    all_merchant = get_data(merchant_name,  "a", "business-name")
    for name in all_merchant:
            merchant.append(name.text)
    merchant_zipcode = get_data(merchant_name, "div", "locality")
    for zc in merchant_zipcode:
        data = re.split(r'(-?\d*\.?\d+)', zc.text)
        city.append(data[0])
        zipcode.append(data[1])

    merchant_address = get_data(merchant_name, "div", "street-address")
    for addr in merchant_address:
        address.append(addr.text)

    merchant_contact = get_data(merchant_name, "div", "phones phone primary")    
    for cont in merchant_contact:
        contact.append(cont.text)
    
    merchant_df['merchant_name'] = pd.Series(merchant)
    merchant_df['address'] = pd.Series(address)
    merchant_df['location'] = pd.Series(city)
    merchant_df['zipcode'] = pd.Series(zipcode)
    merchant_df['contact'] = pd.Series(contact)
    return merchant_df

# %%
walmart_branch = create_df("walmart")[create_df("walmart")['merchant_name'] == 'Walmart']
walmart_branch
# Out:
#    merchant_name                  address       location zipcode  \
# 0        Walmart              780 Lynnway      Lynn, MA    01905
# 1        Walmart         440 Highland Ave    Malden, MA    02148
# 3        Walmart           301 Falls Blvd    Quincy, MA    02169
# 14       Walmart         450 Highland Ave     Salem, MA    01970
# 17       Walmart            740 Middle St  Weymouth, MA    02188
# 27       Walmart  55 Brooksby Village Way   Danvers, MA    01923
#
#            contact
# 0   (781) 592-4300
# 1   (978) 745-8290
# 3   (617) 745-4390
# 14  (978) 825-1713
# 17  (781) 331-0063
# 27  (978) 777-6977

# %%
target_branch = create_df("target")[create_df("target")['merchant_name'] == 'Target']
target_branch
# Out:
#    merchant_name                 address         location zipcode  \
# 0         Target        1341 Boylston St      Boston, MA    02215
# 1         Target    860 Commonwealth Ave      Boston, MA    02215
# 7         Target           7 Allstate Rd  Dorchester, MA    02125
# 8         Target      180 Somerville Ave  Somerville, MA    02143
# 9         Target   564 Massachusetts Ave   Cambridge, MA    02139
# 10        Target             1 Mystic St     Everett, MA    02149
# 11        Target           36 Furlong Dr      Revere, MA    02151
# 12        Target          550 Arsenal St   Watertown, MA    02472
# 13        Target        1 Mystic View Rd     Everett, MA    02149
# 19        Target      221 University Ave    Westwood, MA    02090
# 20        Target  250 Granite St Ste 121   Braintree, MA    02184
# 21        Target     400 Lynn Fells Pkwy      Saugus, MA    01906
# 22        Target        101 Commerce Way      Woburn, MA    01801
# ...

# %%
samsclub_branch = create_df("samsclub")[create_df("samsclub")['merchant_name'] == "Sam's Club"]
samsclub_branch
# Out:
#   merchant_name              address       location zipcode         contact
# 0    Sam's Club       7 Walmart Blvd    Hudson, NH    03051  (603) 882-4600
# 1    Sam's Club  500 Colony Place Rd  Plymouth, MA    02360  (508) 747-2463

# %% [markdown]
# ### Connecting to MySql

# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost".format(user ='root', pw ='system'))

# %%
# creating database
db = 'Grocery_Recommendation_System'
try:
    with engine.connect() as conn:
        conn.execute(f'CREATE DATABASE {db}')
    print("Database created")
except Exception as e:
    print(f"Error while creating database- {e}")
# Out:
# Database created

# %%
#Connecting to Database
engine = create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}".format(user = 'root', pw = 'system', db = 'Grocery_Recommendation_System'))

# %%
#creating merchant table
merchant_df.to_sql('merchant', con=engine, index=False, if_exists='replace')
with engine.connect() as conn:
    conn.execute("ALTER TABLE Grocery_Recommendation_System.merchant ADD merchant_id INT NOT NULL AUTO_INCREMENT, ADD CONSTRAINT PRIMARY KEY(merchant_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.merchant ADD CONSTRAINT `Merchant_id` UNIQUE (merchant_id);")

# %%
#creating walmart_branch table
walmart_branch.to_sql('walmart_branch', con=engine, index=False, if_exists='replace')
with engine.connect() as conn:
    conn.execute("ALTER TABLE walmart_branch ADD COLUMN branch_id INT NOT NULL AUTO_INCREMENT, ADD CONSTRAINT PRIMARY KEY(branch_id);")
    conn.execute("ALTER TABLE walmart_branch ADD CONSTRAINT `Branch_id` UNIQUE (branch_id);")    
    conn.execute("ALTER TABLE Grocery_Recommendation_System.walmart_branch ADD COLUMN merchant_id INT;")
    conn.execute("UPDATE Grocery_Recommendation_System.walmart_branch SET merchant_id = 1")

# %%
#creating target_branch table
target_branch.to_sql('target_branch', con=engine, index=False, if_exists='replace')
with engine.connect() as conn:
    conn.execute("ALTER TABLE Grocery_Recommendation_System.target_branch ADD COLUMN branch_id INT NOT NULL AUTO_INCREMENT, ADD CONSTRAINT PRIMARY KEY(branch_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.target_branch ADD CONSTRAINT `Branch_id` UNIQUE (branch_id);")    
    conn.execute("ALTER TABLE Grocery_Recommendation_System.target_branch ADD COLUMN merchant_id INT;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_branch SET merchant_id = 2")

# %%
#creating samsclub_branch table
samsclub_branch.to_sql('samsclub_branch', con=engine, index=False, if_exists='replace')
with engine.connect() as conn:
    conn.execute("ALTER TABLE Grocery_Recommendation_System.samsclub_branch ADD COLUMN branch_id INT NOT NULL AUTO_INCREMENT, ADD CONSTRAINT PRIMARY KEY(branch_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.samsclub_branch ADD CONSTRAINT `Branch_id` UNIQUE (branch_id);")    
    conn.execute("ALTER TABLE Grocery_Recommendation_System.samsclub_branch ADD COLUMN merchant_id INT;")
    conn.execute("UPDATE Grocery_Recommendation_System.samsclub_branch SET merchant_id = 3")

# %%
walmart_employees = pd.read_csv("walmart_employees.csv")
walmart_employees_df = pd.DataFrame(walmart_employees)
walmart_employees_df.to_sql('walmart_employees', con=engine, index=False, if_exists='replace')

# %%
samsclub_employees = pd.read_csv("samsclub_employees.csv")
samsclub_employees_df = pd.DataFrame(samsclub_employees)
samsclub_employees_df.to_sql('samsclub_employees', con=engine, index=False, if_exists='replace')

# %%
target_employees = pd.read_csv("target_employees.csv")
target_employees_df = pd.DataFrame(target_employees)
target_employees_df.to_sql('target_employees', con=engine, index=False, if_exists='replace')

# %%
walmart_products_df.to_sql('walmart_products_df', con=engine, index=False, if_exists='replace')
with engine.connect() as conn:
    conn.execute("ALTER TABLE Grocery_Recommendation_System.walmart_products_df ADD COLUMN prd_id BIGINT NOT NULL AUTO_INCREMENT, ADD CONSTRAINT PRIMARY KEY(prd_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.walmart_products_df ADD CONSTRAINT `Prd_id` UNIQUE (prd_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.walmart_products_df ADD COLUMN branch_id INT DEFAULT 0;")
    conn.execute("UPDATE Grocery_Recommendation_System.walmart_products_df SET branch_id=1 WHERE zipcode=01905;")
    conn.execute("UPDATE Grocery_Recommendation_System.walmart_products_df SET branch_id=2 WHERE zipcode=02148;")
    conn.execute("UPDATE Grocery_Recommendation_System.walmart_products_df SET branch_id=3 WHERE zipcode=02169;")
    conn.execute("UPDATE Grocery_Recommendation_System.walmart_products_df SET branch_id=4 WHERE zipcode=01970;")
    conn.execute("UPDATE Grocery_Recommendation_System.walmart_products_df SET branch_id=5 WHERE zipcode=02188;")
    conn.execute("UPDATE Grocery_Recommendation_System.walmart_products_df SET branch_id=6 WHERE zipcode=01923;")

# %%
target_products_df.to_sql('target_products_df', con=engine, index=False, if_exists='replace')
with engine.connect() as conn:
    conn.execute("ALTER TABLE Grocery_Recommendation_System.target_products_df ADD COLUMN prd_id BIGINT NOT NULL AUTO_INCREMENT, ADD CONSTRAINT PRIMARY KEY(prd_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.target_products_df ADD CONSTRAINT `Prd_id` UNIQUE (prd_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.target_products_df ADD COLUMN branch_id INT DEFAULT 0;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=1 WHERE zipcode=02215;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=3 WHERE zipcode=02125;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=4 WHERE zipcode=02143;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=5 WHERE zipcode=02139;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=6 WHERE zipcode=02149;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=7 WHERE zipcode=02151;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=8 WHERE zipcode=02472;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=9 WHERE zipcode=02149;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=10 WHERE zipcode=02090;")    
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=11 WHERE zipcode=02184;")
    conn.execute("UPDATE Grocery_Recommendation_System.target_products_df SET branch_id=12 WHERE zipcode=01906;")

# %%
samsclub_products_df.to_sql('samsclub_products_df', con=engine, index=False, if_exists='replace')
with engine.connect() as conn:
    conn.execute("ALTER TABLE Grocery_Recommendation_System.samsclub_products_df ADD COLUMN prd_id BIGINT NOT NULL AUTO_INCREMENT, ADD CONSTRAINT PRIMARY KEY(prd_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.samsclub_products_df ADD CONSTRAINT `Prd_id` UNIQUE (prd_id);")
    conn.execute("ALTER TABLE Grocery_Recommendation_System.samsclub_products_df ADD COLUMN branch_id INT DEFAULT 0;")
    conn.execute("UPDATE Grocery_Recommendation_System.samsclub_products_df SET branch_id=1 WHERE zipcode=03051;")
    conn.execute("UPDATE Grocery_Recommendation_System.samsclub_products_df SET branch_id=2 WHERE zipcode=02360;")

# %%
instacart_products_df.to_sql('instacart_products_df', con=engine, index=False, if_exists='replace')

# %%
target_emp_salary = pd.read_csv("target_emp_salary.csv")
target_emp_salary_df = pd.DataFrame(target_emp_salary)
target_emp_salary_df.to_sql('target_emp_salary', con=engine, index=False, if_exists='replace')

# %%
walmart_emp_salary = pd.read_csv("walmart_emp_salary.csv")
walmart_emp_salary_df = pd.DataFrame(walmart_emp_salary)
walmart_emp_salary_df.to_sql('walmart_emp_salary', con=engine, index=False, if_exists='replace')

# %%
samsclub_emp_salary = pd.read_csv("samsclub_emp_salary.csv")
samsclub_emp_salary_df = pd.DataFrame(samsclub_emp_salary)
samsclub_emp_salary_df.to_sql('samsclub_emp_salary', con=engine, index=False, if_exists='replace')
